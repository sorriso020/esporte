# %% [markdown]
# <a href="https://colab.research.google.com/github/sorriso020/esporte/blob/main/explorando_o_mundo_do_futsal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# explorando o mundo do futsal

# %% [markdown]
# ## Mais Perguntas Sobre Futsal com Código
#
# Aqui estão 5 novas perguntas sobre futsal, cada uma acompanhada de um bloco de código para responder à pergunta.

# %% [markdown]
# ### Pergunta 1: Qual a função principal do pivô no futsal?

# %%
# O código abaixo descreve a função principal do pivô no futsal.
funcao_pivo = "O pivô é o jogador de referência no ataque, buscando receber a bola de costas para a marcação e fazer o pivô (girar) para finalizar ou passar para um companheiro."

print(f"No futsal, a função principal do pivô é: {funcao_pivo}")

# %% [markdown]
# ### Pergunta 2: O que é um "tiro livre direto" no futsal?

# %%
# O código abaixo explica o que é um tiro livre direto no futsal.
tiro_livre_direto = "É uma cobrança de falta onde o jogador pode chutar diretamente para o gol, sem a necessidade de a bola tocar em outro jogador antes."

print(f"Um tiro livre direto no futsal é: {tiro_livre_direto}")

# %% [markdown]
# ### Pergunta 3: Quantas faltas acumulativas um time pode cometer antes de sofrer um tiro livre direto a partir da 10ª falta?

# %%
# O código abaixo define o número de faltas acumulativas antes do tiro livre direto.
faltas_para_tiro_livre_direto = 5

print(f"Um time de futsal pode cometer {faltas_para_tiro_livre_direto} faltas acumulativas em cada tempo. A partir da sexta falta, será cobrado um tiro livre direto.")

# %% [markdown]
# ### Pergunta 4: O que significa a expressão "linha de 10 metros" no futsal?

# %%
# O código abaixo explica o significado da linha de 10 metros no futsal.
linha_10_metros = "É a linha pontilhada na quadra, a 10 metros da linha de fundo, de onde são cobrados os tiros livres diretos a partir da sexta falta acumulativa."

print(f"A 'linha de 10 metros' no futsal é: {linha_10_metros}")

# %% [markdown]
# ### Pergunta 5: Quais são as cores dos cartões usados para advertir ou expulsar jogadores no futsal?

# %%
# O código abaixo lista as cores dos cartões no futsal.
cartoes = ["Cartão Amarelo", "Cartão Vermelho"]

print("No futsal, os cartões usados são:")
for cartao in cartoes:
    print(f"- {cartao}")
